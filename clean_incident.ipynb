# %%
import pandas as pd
from pathlib import Path

# %%
incident_file = Path("..\\project-three/Datasets/INCIDENT.csv")

# %%
incident_df = pd.read_csv(incident_file)
incident_df.head()
# Out:
#      Incident_ID                                            Sources  \
# 0  20220601CAULL  https://www.foxla.com/news/grant-high-school-v...
# 1  20220531LAMON  https://www.wwltv.com/article/news/crime/one-d...
# 2  20220530CAHEL  https://www.sandiegouniontribune.com/news/publ...
# 3  20220529ILDAC  https://abc7chicago.com/chicago-shooting-crime...
# 4  20220526SCMEG  https://abcnews4.com/news/local/coroner-releas...
#
#   Number_News Media_Attention  Reliability       Date Quarter  \
# 0          10        Regional            4   2022/6/1  Summer
# 1         100        National            4  2022/5/31  Spring
# 2           3           Local            4  2022/5/30  Spring
# 3           5           Local            4  2022/5/29  Spring
# 4           5           Local            4  2022/5/26  Spring
#
#                                 School         City State  ... Accomplice  \
# 0  Ulysses S. Grant Senior High School  Los Angeles    CA  ...         No
# ...

# %%
incident_df.dtypes
# Out:
# Incident_ID           object
# Sources               object
# Number_News           object
# Media_Attention       object
# Reliability            int64
# Date                  object
# Quarter               object
# School                object
# City                  object
# State                 object
# School_Level          object
# Location              object
# Location_Type         object
# During_School         object
# Time_Period           object
# First_Shot            object
# Summary               object
# Narrative             object
# Situation             object
# Targets               object
# Accomplice            object
# Hostages              object
# Barricade             object
# Officer_Involved      object
# Bullied               object
# Domestic_Violence     object
# Gang_Related          object
# Preplanned            object
# Shots_Fired           object
# Active_Shooter_FBI    object
# dtype: object

# %%
incident_df['Date'] = pd.to_datetime(incident_df['Date'])

incident_df
# Out:
#         Incident_ID                                            Sources  \
# 0     20220601CAULL  https://www.foxla.com/news/grant-high-school-v...
# 1     20220531LAMON  https://www.wwltv.com/article/news/crime/one-d...
# 2     20220530CAHEL  https://www.sandiegouniontribune.com/news/publ...
# 3     20220529ILDAC  https://abc7chicago.com/chicago-shooting-crime...
# 4     20220526SCMEG  https://abcnews4.com/news/local/coroner-releas...
# ...             ...                                                ...
# 2056  19700323CADAL  https://www.newspapers.com/image/23768017/?ter...
# 2057  19700206OHJOC  https://www.newspapers.com/image/18059538/?ter...
# 2058  19700105DCUNW  https://www.newspapers.com/image/156467116/?te...
# 2059  19700105DCSOW  https://news.google.com/newspapers?id=AfRYAAAA...
# 2060  19700105DCHIW  https://news.google.com/newspapers?id=AfRYAAAA...
#
#      Number_News Media_Attention  Reliability       Date Quarter  \
# ...

# %%
clean_incident_df=incident_df.drop(['Sources', 'Number_News', 'Media_Attention', 'Reliability', 'Quarter', 'Accomplice', 'Hostages', 'Barricade', 'Officer_Involved', 'Bullied', 'Domestic_Violence', 'Gang_Related', 'Preplanned', 'Shots_Fired', 'Active_Shooter_FBI', 'Location', "Location_Type", 'Time_Period', 'First_Shot', 'Summary', 'Narrative', 'Situation', 'School_Level'], axis=1)

# %%
clean_incident_df
# Out:
#         Incident_ID       Date                               School  \
# 0     20220601CAULL 2022-06-01  Ulysses S. Grant Senior High School
# 1     20220531LAMON 2022-05-31              Morris Jeff High School
# 2     20220530CAHEL 2022-05-30                    Helix High School
# 3     20220529ILDAC 2022-05-29         Daniel Webster Public School
# 4     20220526SCMEG 2022-05-26          Mevers School of Excellence
# ...             ...        ...                                  ...
# 2056  19700323CADAL 1970-03-23       David Starr Jordan High School
# 2057  19700206OHJOC 1970-02-06          John F. Kennedy High School
# 2058  19700105DCUNW 1970-01-05                  Unnamed High School
# 2059  19700105DCSOW 1970-01-05                    Sousa Junior High
# 2060  19700105DCHIW 1970-01-05              Hine Junior High School
#
#              City State During_School           Targets
# 0     Los Angeles    CA           Yes  Victims Targeted
# ...

# %%
clean_incident_df.to_csv("clean_incident.csv", index=False, header=True)
