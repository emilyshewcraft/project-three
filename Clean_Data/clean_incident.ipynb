# %%
import pandas as pd
from pathlib import Path

# %%
incident_file = Path("../Datasets/INCIDENT.csv")
incident_df = pd.read_csv(incident_file)
incident_df.head()
# Out:
#      Incident_ID                                            Sources  \
# 0  20190702AKWIA  https://www.citynews1130.com/2019/07/03/teen-s...
# 1  20181003AKDEA  https://www.adn.com/alaska-news/crime-courts/2...
# 2  20050901AKDIA  https://www.columbine-angels.com/School_Violen...
# 3  20000110AKBAA  Anchorage Daily News - Fight Leads to Gunshots...
# 4  19970219AKBEB  https://www.adn.com/alaska-news/2017/02/18/eva...
#
#   Number_News Media_Attention  Reliability       Date Quarter  \
# 0         NaN             NaN          4.0   7/2/2019  Summer
# 1           2           Local          4.0  10/3/2018    Fall
# 2         NaN             NaN          1.0   9/1/2005    Fall
# 3         NaN             NaN          1.0  1/10/2000  Winter
# 4         NaN             NaN          2.0  2/19/1997  Winter
#
#                                 School       City State  ...  Accomplice  \
# 0           Williwaw Elementary School  Anchorage    AK  ...         NaN
# 1  Denali Montessori Elementary School  Anchorage    AK  ...          No
# 2                   Dimond High School  Anchorage    AK  ...          No
# 3                 Bartlett High School  Anchorage    AK  ...          No
# 4          Bethel Regional High School     Bethel    AK  ...         NaN
#
#    Hostages Barricade Officer_Involved Bullied Domestic_Violence Gang_Related  \
# 0        No        No               No      No                No           No
# 1        No        No               No      No               Yes           No
# 2        No        No               No      No                No           No
# 3        No        No               No      No                No           No
# 4        No        No               No     Yes                No           No
#
#   Preplanned Shots_Fired Active_Shooter_FBI
# 0         No         <10                 No
# 1         No           1                 No
# 2         No         <10                NaN
# 3         No           2                NaN
# 4        Yes         NaN                Yes
#
# [5 rows x 32 columns]

# %%
incident_df.dtypes
# Out:
# Incident_ID            object
# Sources                object
# Number_News            object
# Media_Attention        object
# Reliability           float64
# Date                   object
# Quarter                object
# School                 object
# City                   object
# State                  object
# City_Lat              float64
# City_Lon              float64
# School_Level           object
# Location               object
# Location_Type          object
# During_School          object
# Time_Period            object
# First_Shot             object
# Summary                object
# Narrative              object
# Situation              object
# Targets                object
# Accomplice             object
# Hostages               object
# Barricade              object
# Officer_Involved       object
# Bullied                object
# Domestic_Violence      object
# Gang_Related           object
# Preplanned             object
# Shots_Fired            object
# Active_Shooter_FBI     object
# dtype: object

# %%
incident_df['Date'] = pd.to_datetime(incident_df['Date'])

incident_df
# Out:
#         Incident_ID                                            Sources  \
# 0     20190702AKWIA  https://www.citynews1130.com/2019/07/03/teen-s...
# 1     20181003AKDEA  https://www.adn.com/alaska-news/crime-courts/2...
# 2     20050901AKDIA  https://www.columbine-angels.com/School_Violen...
# 3     20000110AKBAA  Anchorage Daily News - Fight Leads to Gunshots...
# 4     19970219AKBEB  https://www.adn.com/alaska-news/2017/02/18/eva...
# ...             ...                                                ...
# 2058  19780209WVHAS  https://www.wvgazettemail.com/news/cops_and_co...
# 2059  19860516WYCOC  https://www.wyohistory.org/encyclopedia/cokevi...
# 2060  19930917WYCES  http://buffalonews.com/1993/09/18/gunman-wound...
# 2061            NaN                                                NaN
# 2062            NaN                                                NaN
#
#      Number_News Media_Attention  Reliability       Date Quarter  \
# 0            NaN             NaN          4.0 2019-07-02  Summer
# 1              2           Local          4.0 2018-10-03    Fall
# 2            NaN             NaN          1.0 2005-09-01    Fall
# 3            NaN             NaN          1.0 2000-01-10  Winter
# 4            NaN             NaN          2.0 1997-02-19  Winter
# ...          ...             ...          ...        ...     ...
# 2058         NaN             NaN          2.0 1978-02-09  Winter
# 2059         NaN             NaN          2.0 1986-05-16  Spring
# 2060         NaN             NaN          2.0 1993-09-17    Fall
# 2061         NaN             NaN          NaN        NaT     NaN
# 2062         NaN             NaN          NaN        NaT     NaN
#
#                                    School        City State  ...  Accomplice  \
# 0              Williwaw Elementary School   Anchorage    AK  ...         NaN
# 1     Denali Montessori Elementary School   Anchorage    AK  ...          No
# 2                      Dimond High School   Anchorage    AK  ...          No
# 3                    Bartlett High School   Anchorage    AK  ...          No
# 4             Bethel Regional High School      Bethel    AK  ...         NaN
# ...                                   ...         ...   ...  ...         ...
# 2058             Hayes Junior High School  St. Albans    WV  ...          No
# 2059          Cokeville Elementary School   Cokeville    WY  ...         Yes
# 2060           Central Junior High School    Sheridan    WY  ...          No
# 2061                                  NaN         NaN   NaN  ...         NaN
# 2062                                  NaN         NaN   NaN  ...         NaN
#
#       Hostages Barricade Officer_Involved Bullied Domestic_Violence  \
# 0           No        No               No      No                No
# 1           No        No               No      No               Yes
# 2           No        No               No      No                No
# 3           No        No               No      No                No
# 4           No        No               No     Yes                No
# ...        ...       ...              ...     ...               ...
# 2058        No        No               No     Yes                No
# 2059       Yes        No               No      No                No
# 2060        No        No               No      No                No
# 2061       NaN       NaN              NaN     NaN               NaN
# 2062       NaN       NaN              NaN     NaN               NaN
#
#      Gang_Related Preplanned Shots_Fired Active_Shooter_FBI
# 0              No         No         <10                 No
# 1              No         No           1                 No
# 2              No         No         <10                NaN
# 3              No         No           2                NaN
# 4              No        Yes         NaN                Yes
# ...           ...        ...         ...                ...
# 2058           No         No           3                NaN
# 2059           No        Yes         >10                Yes
# 2060           No         No          30                Yes
# 2061          NaN        NaN         NaN                NaN
# 2062          NaN        NaN         NaN                NaN
#
# [2063 rows x 32 columns]

# %%
clean_incident_df=incident_df.drop(['Sources', 'Number_News', 'Reliability', 'Quarter', 'Accomplice', 'Hostages', 'Barricade', 'Officer_Involved', 'Bullied', 'Domestic_Violence', 'Gang_Related', 'Preplanned', 'Shots_Fired', 'Active_Shooter_FBI', 'Location', "Location_Type", 'Time_Period', 'First_Shot', 'Summary', 'Narrative', 'Situation', 'During_School'], axis=1)

# %%
clean_incident_df
# Out:
#         Incident_ID Media_Attention       Date  \
# 0     20190702AKWIA             NaN 2019-07-02
# 1     20181003AKDEA           Local 2018-10-03
# 2     20050901AKDIA             NaN 2005-09-01
# 3     20000110AKBAA             NaN 2000-01-10
# 4     19970219AKBEB             NaN 1997-02-19
# ...             ...             ...        ...
# 2058  19780209WVHAS             NaN 1978-02-09
# 2059  19860516WYCOC             NaN 1986-05-16
# 2060  19930917WYCES             NaN 1993-09-17
# 2061            NaN             NaN        NaT
# 2062            NaN             NaN        NaT
#
#                                    School        City State   City_Lat  \
# 0              Williwaw Elementary School   Anchorage    AK  61.218056
# 1     Denali Montessori Elementary School   Anchorage    AK  61.218056
# 2                      Dimond High School   Anchorage    AK  61.218056
# 3                    Bartlett High School   Anchorage    AK  61.218056
# 4             Bethel Regional High School      Bethel    AK  60.804878
# ...                                   ...         ...   ...        ...
# 2058             Hayes Junior High School  St. Albans    WV  38.373280
# 2059          Cokeville Elementary School   Cokeville    WY  42.085670
# 2060           Central Junior High School    Sheridan    WY  44.804010
# 2061                                  NaN         NaN   NaN        NaN
# 2062                                  NaN         NaN   NaN        NaN
#
#         City_Lon School_Level           Targets
# 0    -149.900284   Elementary               NaN
# 1    -149.900284   Elementary  Victims Targeted
# 2    -149.900284         High  Victims Targeted
# 3    -149.900284         High  Victims Targeted
# 4    -161.782150         High   Random Shooting
# ...          ...          ...               ...
# 2058  -81.842280  Junior High  Victims Targeted
# 2059 -110.953710   Elementary           Neither
# 2060 -106.962810  Junior High   Random Shooting
# 2061         NaN          NaN               NaN
# 2062         NaN          NaN               NaN
#
# [2063 rows x 10 columns]

# %%
def organize_level(string):
    if string == "Elementary":
        return "Elementary"
    elif string == "High":
        return "High"
    elif string == "Junior High":
        return "Junior High"
    elif string == "K-12":
        return "K-12"
    elif string == "K-8":
        return "K-8"
    elif string == "Middle":
        return "Middle"
    elif string == "Other":
        return "Other"
    else:
        return None

clean_incident_df['School_Level'].apply(organize_level)
clean_incident_df.head()
# Out:
#      Incident_ID Media_Attention       Date  \
# 0  20190702AKWIA             NaN 2019-07-02
# 1  20181003AKDEA           Local 2018-10-03
# 2  20050901AKDIA             NaN 2005-09-01
# 3  20000110AKBAA             NaN 2000-01-10
# 4  19970219AKBEB             NaN 1997-02-19
#
#                                 School       City State   City_Lat  \
# 0           Williwaw Elementary School  Anchorage    AK  61.218056
# 1  Denali Montessori Elementary School  Anchorage    AK  61.218056
# 2                   Dimond High School  Anchorage    AK  61.218056
# 3                 Bartlett High School  Anchorage    AK  61.218056
# 4          Bethel Regional High School     Bethel    AK  60.804878
#
#      City_Lon School_Level           Targets
# 0 -149.900284   Elementary               NaN
# 1 -149.900284   Elementary  Victims Targeted
# 2 -149.900284         High  Victims Targeted
# 3 -149.900284         High  Victims Targeted
# 4 -161.782150         High   Random Shooting

# %%
def organize_target(string):
    if string == "Random Shooting":
        return "Random Shooting"
    elif string == "Victims Targeted":
        return "Victims Targeted"
    elif string == "Both":
        return "Both"
    elif string == "Neither":
        return "Neither"
    else:
        return None

clean_incident_df['Targets'].apply(organize_target)
clean_incident_df.dropna(subset=['Targets'], inplace=True)
clean_incident_df.head()
# Out:
#      Incident_ID Media_Attention       Date  \
# 1  20181003AKDEA           Local 2018-10-03
# 2  20050901AKDIA             NaN 2005-09-01
# 3  20000110AKBAA             NaN 2000-01-10
# 4  19970219AKBEB             NaN 1997-02-19
# 6  20170110ALALA             NaN 2017-01-10
#
#                                 School            City State   City_Lat  \
# 1  Denali Montessori Elementary School       Anchorage    AK  61.218056
# 2                   Dimond High School       Anchorage    AK  61.218056
# 3                 Bartlett High School       Anchorage    AK  61.218056
# 4          Bethel Regional High School          Bethel    AK  60.804878
# 6         Alexander City Middle School  Alexander City    AL  32.944012
#
#      City_Lon School_Level           Targets
# 1 -149.900284   Elementary  Victims Targeted
# 2 -149.900284         High  Victims Targeted
# 3 -149.900284         High  Victims Targeted
# 4 -161.782150         High   Random Shooting
# 6  -85.953853       Middle           Neither

# %%
clean_incident_df.to_csv("clean_incident.csv", index=False, header=True)
