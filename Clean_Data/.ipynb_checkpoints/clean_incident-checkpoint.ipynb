# %%
import pandas as pd
from pathlib import Path

# %%
incident_file = Path("../Datasets/INCIDENT.csv")
incident_df = pd.read_csv(incident_file)
incident_df.head()
# Out:
#      Incident_ID                                            Sources  \
# 0  20220601CAULL  https://www.foxla.com/news/grant-high-school-v...
# 1  20220531LAMON  https://www.wwltv.com/article/news/crime/one-d...
# 2  20220530CAHEL  https://www.sandiegouniontribune.com/news/publ...
# 3  20220529ILDAC  https://abc7chicago.com/chicago-shooting-crime...
# 4  20220526SCMEG  https://abcnews4.com/news/local/coroner-releas...
#
#   Number_News Media_Attention  Reliability       Date Quarter  \
# 0          10        Regional            4   2022/6/1  Summer
# 1         100        National            4  2022/5/31  Spring
# 2           3           Local            4  2022/5/30  Spring
# 3           5           Local            4  2022/5/29  Spring
# 4           5           Local            4  2022/5/26  Spring
#
#                                 School         City State  ... Accomplice  \
# 0  Ulysses S. Grant Senior High School  Los Angeles    CA  ...         No
# 1              Morris Jeff High School  New Orleans    LA  ...         No
# 2                    Helix High School      La Mesa    CA  ...         No
# 3         Daniel Webster Public School      Chicago    IL  ...        Yes
# 4          Mevers School of Excellence  Goose Creek    SC  ...        NaN
#
#   Hostages Barricade Officer_Involved Bullied Domestic_Violence Gang_Related  \
# 0       No        No               No      No                No          Yes
# 1       No        No               No      No                No           No
# 2       No        No               No      No                No          NaN
# 3       No        No               No      No                No          NaN
# 4       No        No               No      No               NaN          NaN
#
#   Preplanned Shots_Fired Active_Shooter_FBI
# 0         No         NaN                 No
# 1         No          99                 No
# 2         No          99                 No
# 3         No          97                 No
# 4         No          99                 No
#
# [5 rows x 30 columns]

# %%
incident_df.dtypes
# Out:
# Incident_ID           object
# Sources               object
# Number_News           object
# Media_Attention       object
# Reliability            int64
# Date                  object
# Quarter               object
# School                object
# City                  object
# State                 object
# School_Level          object
# Location              object
# Location_Type         object
# During_School         object
# Time_Period           object
# First_Shot            object
# Summary               object
# Narrative             object
# Situation             object
# Targets               object
# Accomplice            object
# Hostages              object
# Barricade             object
# Officer_Involved      object
# Bullied               object
# Domestic_Violence     object
# Gang_Related          object
# Preplanned            object
# Shots_Fired           object
# Active_Shooter_FBI    object
# dtype: object

# %%
incident_df['Date'] = pd.to_datetime(incident_df['Date'])

incident_df
# Out:
#         Incident_ID                                            Sources  \
# 0     20220601CAULL  https://www.foxla.com/news/grant-high-school-v...
# 1     20220531LAMON  https://www.wwltv.com/article/news/crime/one-d...
# 2     20220530CAHEL  https://www.sandiegouniontribune.com/news/publ...
# 3     20220529ILDAC  https://abc7chicago.com/chicago-shooting-crime...
# 4     20220526SCMEG  https://abcnews4.com/news/local/coroner-releas...
# ...             ...                                                ...
# 2056  19700323CADAL  https://www.newspapers.com/image/23768017/?ter...
# 2057  19700206OHJOC  https://www.newspapers.com/image/18059538/?ter...
# 2058  19700105DCUNW  https://www.newspapers.com/image/156467116/?te...
# 2059  19700105DCSOW  https://news.google.com/newspapers?id=AfRYAAAA...
# 2060  19700105DCHIW  https://news.google.com/newspapers?id=AfRYAAAA...
#
#      Number_News Media_Attention  Reliability       Date Quarter  \
# 0             10        Regional            4 2022-06-01  Summer
# 1            100        National            4 2022-05-31  Spring
# 2              3           Local            4 2022-05-30  Spring
# 3              5           Local            4 2022-05-29  Spring
# 4              5           Local            4 2022-05-26  Spring
# ...          ...             ...          ...        ...     ...
# 2056         NaN             NaN            2 1970-03-23  Spring
# 2057         NaN             NaN            2 1970-02-06  Winter
# 2058         NaN             NaN            2 1970-01-05  Winter
# 2059         NaN             NaN            3 1970-01-05  Winter
# 2060         NaN             NaN            3 1970-01-05  Winter
#
#                                    School         City State  ... Accomplice  \
# 0     Ulysses S. Grant Senior High School  Los Angeles    CA  ...         No
# 1                 Morris Jeff High School  New Orleans    LA  ...         No
# 2                       Helix High School      La Mesa    CA  ...         No
# 3            Daniel Webster Public School      Chicago    IL  ...        Yes
# 4             Mevers School of Excellence  Goose Creek    SC  ...        NaN
# ...                                   ...          ...   ...  ...        ...
# 2056       David Starr Jordan High School   Long Beach    CA  ...        Yes
# 2057          John F. Kennedy High School    Cleveland    OH  ...         No
# 2058                  Unnamed High School   Washington    DC  ...        Yes
# 2059                    Sousa Junior High   Washington    DC  ...         No
# 2060              Hine Junior High School   Washington    DC  ...        Yes
#
#      Hostages Barricade Officer_Involved Bullied Domestic_Violence  \
# 0          No        No               No      No                No
# 1          No        No               No      No                No
# 2          No        No               No      No                No
# 3          No        No               No      No                No
# 4          No        No               No      No               NaN
# ...       ...       ...              ...     ...               ...
# 2056       No        No               No      No                No
# 2057       No        No               No      No                No
# 2058       No        No               No      No                No
# 2059       No        No               No      No                No
# 2060       No        No               No      No                No
#
#      Gang_Related Preplanned Shots_Fired Active_Shooter_FBI
# 0             Yes         No         NaN                 No
# 1              No         No          99                 No
# 2             NaN         No          99                 No
# 3             NaN         No          97                 No
# 4             NaN         No          99                 No
# ...           ...        ...         ...                ...
# 2056           No         No         <10                NaN
# 2057           No         No           4                NaN
# 2058           No         No           2                NaN
# 2059           No         No           1                NaN
# 2060           No         No           1                NaN
#
# [2061 rows x 30 columns]

# %%
clean_incident_df=incident_df.drop(['Sources', 'Number_News', 'Reliability', 'Quarter', 'Accomplice', 'Hostages', 'Barricade', 'Officer_Involved', 'Bullied', 'Domestic_Violence', 'Gang_Related', 'Preplanned', 'Shots_Fired', 'Active_Shooter_FBI', 'Location', "Location_Type", 'Time_Period', 'First_Shot', 'Summary', 'Narrative', 'Situation', 'During_School'], axis=1)

# %%
clean_incident_df
# Out:
#         Incident_ID Media_Attention       Date  \
# 0     20220601CAULL        Regional 2022-06-01
# 1     20220531LAMON        National 2022-05-31
# 2     20220530CAHEL           Local 2022-05-30
# 3     20220529ILDAC           Local 2022-05-29
# 4     20220526SCMEG           Local 2022-05-26
# ...             ...             ...        ...
# 2056  19700323CADAL             NaN 1970-03-23
# 2057  19700206OHJOC             NaN 1970-02-06
# 2058  19700105DCUNW             NaN 1970-01-05
# 2059  19700105DCSOW             NaN 1970-01-05
# 2060  19700105DCHIW             NaN 1970-01-05
#
#                                    School         City State School_Level  \
# 0     Ulysses S. Grant Senior High School  Los Angeles    CA         High
# 1                 Morris Jeff High School  New Orleans    LA         High
# 2                       Helix High School      La Mesa    CA         High
# 3            Daniel Webster Public School      Chicago    IL   Elementary
# 4             Mevers School of Excellence  Goose Creek    SC          K-8
# ...                                   ...          ...   ...          ...
# 2056       David Starr Jordan High School   Long Beach    CA         High
# 2057          John F. Kennedy High School    Cleveland    OH         High
# 2058                  Unnamed High School   Washington    DC         High
# 2059                    Sousa Junior High   Washington    DC  Junior High
# 2060              Hine Junior High School   Washington    DC         High
#
#                Targets
# 0     Victims Targeted
# 1                 Both
# 2     Victims Targeted
# 3                 Both
# 4     Victims Targeted
# ...                ...
# 2056           Neither
# 2057  Victims Targeted
# 2058  Victims Targeted
# 2059   Random Shooting
# 2060   Random Shooting
#
# [2061 rows x 8 columns]

# %%
def organize_level(string):
    if string == "Elementary":
        return "Elementary"
    elif string == "High":
        return "High"
    elif string == "Junior High":
        return "Junior High"
    elif string == "K-12":
        return "K-12"
    elif string == "K-8":
        return "K-8"
    elif string == "Middle":
        return "Middle"
    elif string == "Other":
        return "Other"
    else:
        return None

clean_incident_df['School_Level'].apply(organize_level)
clean_incident_df.head()
# Out:
#      Incident_ID Media_Attention       Date  \
# 0  20220601CAULL        Regional 2022-06-01
# 1  20220531LAMON        National 2022-05-31
# 2  20220530CAHEL           Local 2022-05-30
# 3  20220529ILDAC           Local 2022-05-29
# 4  20220526SCMEG           Local 2022-05-26
#
#                                 School         City State School_Level  \
# 0  Ulysses S. Grant Senior High School  Los Angeles    CA         High
# 1              Morris Jeff High School  New Orleans    LA         High
# 2                    Helix High School      La Mesa    CA         High
# 3         Daniel Webster Public School      Chicago    IL   Elementary
# 4          Mevers School of Excellence  Goose Creek    SC          K-8
#
#             Targets
# 0  Victims Targeted
# 1              Both
# 2  Victims Targeted
# 3              Both
# 4  Victims Targeted

# %%
def organize_target(string):
    if string == "Random Shooting":
        return "Random Shooting"
    elif string == "Victims Targeted":
        return "Victims Targeted"
    elif string == "Both":
        return "Both"
    elif string == "Neither":
        return "Neither"
    else:
        return None

clean_incident_df['Targets'].apply(organize_target)
clean_incident_df.head()
# Out:
#      Incident_ID Media_Attention       Date  \
# 0  20220601CAULL        Regional 2022-06-01
# 1  20220531LAMON        National 2022-05-31
# 2  20220530CAHEL           Local 2022-05-30
# 3  20220529ILDAC           Local 2022-05-29
# 4  20220526SCMEG           Local 2022-05-26
#
#                                 School         City State School_Level  \
# 0  Ulysses S. Grant Senior High School  Los Angeles    CA         High
# 1              Morris Jeff High School  New Orleans    LA         High
# 2                    Helix High School      La Mesa    CA         High
# 3         Daniel Webster Public School      Chicago    IL   Elementary
# 4          Mevers School of Excellence  Goose Creek    SC          K-8
#
#             Targets
# 0  Victims Targeted
# 1              Both
# 2  Victims Targeted
# 3              Both
# 4  Victims Targeted

# %%
clean_incident_df.to_csv("clean_incident.csv", index=False, header=True)
