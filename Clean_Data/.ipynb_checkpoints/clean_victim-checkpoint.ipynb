# %%
# Dependencies
import pandas as pd
from pathlib import Path

# %%
# Save path to the data set as a variable.
victim_file = Path("../Datasets/VICTIM.csv")

# %%
# Use Pandas to the read data.
victim_df = pd.read_csv(victim_file)
victim_df.head()
# Out:
#       incidentid race   injury gender schoolaffiliation   age
# 0  19700105DCHIW  NaN    Fatal   Male           Student    15
# 1  19700105DCSOW  NaN  Wounded   Male           Student  Teen
# 2  19700105DCUNW  NaN     None   Male           Unknown    16
# 3  19700206OHJOC  NaN  Wounded   Male           Student    18
# 4  19700323CADAL  NaN  Wounded   Male    Security Guard    44

# %%
def pull_strings(string):
    if string == "Teen":
        return "Teen"
    elif string == "Adult":
        return "Adult"
    elif string == "Child":
        return "Child"
    elif string == "Officer":
        return "Officer"
    else:
        return None

victim_df['age_cat'] = victim_df['age'].apply(pull_strings)
victim_df.head(10)
# Out:
#       incidentid   race   injury   gender schoolaffiliation   age age_cat
# 0  19700105DCHIW    NaN    Fatal     Male           Student    15    None
# 1  19700105DCSOW    NaN  Wounded     Male           Student  Teen    Teen
# 2  19700105DCUNW    NaN     None     Male           Unknown    16    None
# 3  19700206OHJOC    NaN  Wounded     Male           Student    18    None
# 4  19700323CADAL    NaN  Wounded     Male    Security Guard    44    None
# 5  19700323CADAL    NaN  Wounded     Male           Student    16    None
# 6  19700415ARPIP  Black    Fatal     Male           Student    20    None
# 7  19700415ARPIP  Black  Wounded  Unknown           Student  Teen    Teen
# 8  19700415ARPIP  Black  Wounded  Unknown           Student  Teen    Teen
# 9  19700415ARPIP  Black  Wounded  Unknown           Student  Teen    Teen

# %%
def replace_strings(string):
    if string == "Teen":
        return 0
    elif string == "Adult":
        return 0
    elif string == "Child":
        return 0
    elif string == "Officer":
        return 0
    elif string == "null":
        return 0
    elif string == "":
        return 0
    else:
        return string

victim_df['age'] = victim_df['age'].apply(replace_strings)
victim_df.head(10)
# Out:
#       incidentid   race   injury   gender schoolaffiliation age age_cat
# 0  19700105DCHIW    NaN    Fatal     Male           Student  15    None
# 1  19700105DCSOW    NaN  Wounded     Male           Student   0    Teen
# 2  19700105DCUNW    NaN     None     Male           Unknown  16    None
# 3  19700206OHJOC    NaN  Wounded     Male           Student  18    None
# 4  19700323CADAL    NaN  Wounded     Male    Security Guard  44    None
# 5  19700323CADAL    NaN  Wounded     Male           Student  16    None
# 6  19700415ARPIP  Black    Fatal     Male           Student  20    None
# 7  19700415ARPIP  Black  Wounded  Unknown           Student   0    Teen
# 8  19700415ARPIP  Black  Wounded  Unknown           Student   0    Teen
# 9  19700415ARPIP  Black  Wounded  Unknown           Student   0    Teen

# %%
victim_df['age'] = victim_df['age'].fillna(0)
victim_df["age"] = victim_df["age"].astype(int)
victim_df.dtypes
# Out:
# incidentid           object
# race                 object
# injury               object
# gender               object
# schoolaffiliation    object
# age                   int32
# age_cat              object
# dtype: object

# %%
def categorize(age):
    if age < 12 and age > 0:
        return "Child"
    elif age < 21 and age > 12:
        return "Teen"
    elif age > 21:
        return "Adult"
    else:
        return 0

victim_df['age_cat2'] = victim_df['age'].apply(categorize)
victim_df.head(10)
# Out:
#       incidentid   race   injury   gender schoolaffiliation  age age_cat  \
# 0  19700105DCHIW    NaN    Fatal     Male           Student   15    None
# 1  19700105DCSOW    NaN  Wounded     Male           Student    0    Teen
# 2  19700105DCUNW    NaN     None     Male           Unknown   16    None
# 3  19700206OHJOC    NaN  Wounded     Male           Student   18    None
# 4  19700323CADAL    NaN  Wounded     Male    Security Guard   44    None
# 5  19700323CADAL    NaN  Wounded     Male           Student   16    None
# 6  19700415ARPIP  Black    Fatal     Male           Student   20    None
# 7  19700415ARPIP  Black  Wounded  Unknown           Student    0    Teen
# 8  19700415ARPIP  Black  Wounded  Unknown           Student    0    Teen
# 9  19700415ARPIP  Black  Wounded  Unknown           Student    0    Teen
#
#   age_cat2
# 0     Teen
# 1        0
# 2     Teen
# 3     Teen
# 4    Adult
# 5     Teen
# 6     Teen
# 7        0
# 8        0
# 9        0

# %%
victim_df['age_cat'] = victim_df['age_cat'].fillna(victim_df['age_cat2'])
victim_df.head(10)
# Out:
#       incidentid   race   injury   gender schoolaffiliation  age age_cat  \
# 0  19700105DCHIW    NaN    Fatal     Male           Student   15    Teen
# 1  19700105DCSOW    NaN  Wounded     Male           Student    0    Teen
# 2  19700105DCUNW    NaN     None     Male           Unknown   16    Teen
# 3  19700206OHJOC    NaN  Wounded     Male           Student   18    Teen
# 4  19700323CADAL    NaN  Wounded     Male    Security Guard   44   Adult
# 5  19700323CADAL    NaN  Wounded     Male           Student   16    Teen
# 6  19700415ARPIP  Black    Fatal     Male           Student   20    Teen
# 7  19700415ARPIP  Black  Wounded  Unknown           Student    0    Teen
# 8  19700415ARPIP  Black  Wounded  Unknown           Student    0    Teen
# 9  19700415ARPIP  Black  Wounded  Unknown           Student    0    Teen
#
#   age_cat2
# 0     Teen
# 1        0
# 2     Teen
# 3     Teen
# 4    Adult
# 5     Teen
# 6     Teen
# 7        0
# 8        0
# 9        0

# %%
clean_victim_df = victim_df[["incidentid", "injury", "age_cat"]]
clean_victim_df.head(10)
# Out:
#       incidentid   injury age_cat
# 0  19700105DCHIW    Fatal    Teen
# 1  19700105DCSOW  Wounded    Teen
# 2  19700105DCUNW     None    Teen
# 3  19700206OHJOC  Wounded    Teen
# 4  19700323CADAL  Wounded   Adult
# 5  19700323CADAL  Wounded    Teen
# 6  19700415ARPIP    Fatal    Teen
# 7  19700415ARPIP  Wounded    Teen
# 8  19700415ARPIP  Wounded    Teen
# 9  19700415ARPIP  Wounded    Teen

# %%
clean_victim_df.rename(columns={'incidentid': "Incident_ID",
                                'injury': "Injury",
                                'age_cat': "Age"}, inplace=True)
clean_victim_df.head()
# Out:
# C:\Users\carlt\AppData\Local\Temp\ipykernel_8424\3059068117.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_victim_df.rename(columns={'incidentid': "Incident_ID",
#      Incident_ID   Injury    Age
# 0  19700105DCHIW    Fatal   Teen
# 1  19700105DCSOW  Wounded   Teen
# 2  19700105DCUNW     None   Teen
# 3  19700206OHJOC  Wounded   Teen
# 4  19700323CADAL  Wounded  Adult

# %%
clean_victim_df.to_csv("clean_victim.csv", index=False, header=True)

# %%
#Group by victim age
clean_victim_df.groupby('Age')['Incident_ID'].count().reset_index().sort_values('Incident_ID', ascending=False)
# Out:
#        Age  Incident_ID
# 4     Teen         1781
# 1    Adult          633
# 0        0          347
# 2    Child          331
# 3  Officer            1

# %%
#Group by victim injury
clean_victim_df.groupby('Injury')['Incident_ID'].count().reset_index().sort_values('Incident_ID', ascending=False)
# Out:
#            Injury  Incident_ID
# 3         Wounded         1835
# 0           Fatal          683
# 2            None          481
# 1  Minor Injuries           94
